# %%
import datetime
import fileinput
import glob
import json
import os
import re
import subprocess
import sys

# %% [markdown]
# ## Data

# %%
def read_mut_data(path): 
    input_file = open(path, "r")
    project_targets = json.loads(input_file.read())
    input_file.close()
    return project_targets

# %% [markdown]
# ## Test runner

# %%
def install_parent_module(target):
    os.chdir(target["parent-module-path"])
    process = subprocess.Popen(['mvn', 'clean', 'install', '-DskipTests'],
                               stdout=subprocess.PIPE, 
                               stderr=subprocess.PIPE)
    output_to_log("[LOG] Invoked a clean install of the parent module with {}".format(process.args))
    stdout, stderr = process.communicate()
    output_to_log(stdout.decode("utf-8"))
    output_to_log(stderr.decode("utf-8"))
    output_to_log("---------------------------------------------------")
    os.chdir(experiment_directory)

# %%
def run_mvn_test(target):
    os.chdir(target["test-module-path"])
    output_to_log("[LOG] In test module directory " + os.getcwd())
    # run tests
    test_class = target["test-file"].replace(".java", "")
    run_test_class = "-Dtest=" + test_class
    process = subprocess.Popen(['mvn', 'test', run_test_class],
                               stdout=subprocess.PIPE, 
                               stderr=subprocess.PIPE)
    output_to_log("[LOG] Invoked tests with {}".format(process.args))
    stdout, stderr = process.communicate()
    output_to_log(stdout.decode("utf-8"))
    output_to_log(stderr.decode("utf-8"))
    
    output_to_log("---------------------------------------------------")

    # store result here
    result = re.search(r"(Tests run:.*)\n",
                       stdout.decode("utf-8")).group(1)
        
    process = subprocess.Popen(['mvn', 'clean'],
                               stdout=subprocess.PIPE, 
                               stderr=subprocess.PIPE)
    output_to_log("[LOG] Cleaned targets with {}".format(process.args))
    stdout, stderr = process.communicate()
    output_to_log(stdout.decode("utf-8"))
    output_to_log(stderr.decode("utf-8"))
    
    output_to_log("---------------------------------------------------")

    # cd back into experiment directory
    os.chdir(experiment_directory)
    output_to_log("[LOG] In experiment directory " + os.getcwd())
    output_to_log("---------------------------------------------------")
    
    return result

# %%
def run_baseline_tests_with_no_oracles(target):
    output_to_log("[BASELINE] Not evaluating any oracle")
    # comment out all assertEquals and Mockito.verify statements"
    replace_original_RICK_test_with_variant(target, "baseline")
    
    # cd into test module, run tests, cd back into experiments directory
    result_baseline = run_mvn_test(target)
    
    # restore original test
    restore_original_RICK_test(target)
    output_to_log("---------------------------------------------------")
    return result_baseline

# %%
def run_oo(target):
    output_to_log("[OO] Evaluating only OO")
    replace_original_RICK_test_with_variant(target, "oo")

    # cd into test module, run tests, cd back into experiments directory
    result_oo = run_mvn_test(target)
    
    # restore original test
    restore_original_RICK_test(target)
    output_to_log("---------------------------------------------------")
    return result_oo

# %%
def run_po(target):
    output_to_log("[PO] Evaluating only PO")
    replace_original_RICK_test_with_variant(target, "po")
    
    # cd into test module, run tests, cd back into experiments directory
    result_po = run_mvn_test(target)
    
    # restore original test
    restore_original_RICK_test(target)
    output_to_log("---------------------------------------------------")
    return result_po

# %%
def run_co(target):
    output_to_log("[CO] Evaluating only CO")
    replace_original_RICK_test_with_variant(target, "co")
    
    # cd into test module, run tests, cd back into experiments directory
    result_co = run_mvn_test(target)
    
    # restore original test
    restore_original_RICK_test(target)
    output_to_log("---------------------------------------------------")
    return result_co

# %%
def run_all_oracles(target):
    output_to_log("[ALL] Evaluating (OO +) PO + CO")
    # restore original tests
    restore_original_RICK_test(target)
    
    # cd into test module, run tests, cd back into experiments directory
    result_all = run_mvn_test(target)
    
    output_to_log("---------------------------------------------------")
    return result_all

# %% [markdown]
# ## Util

# %%
def output_to_log(message):
    with open(mut_mutation_log_path, 'a+') as logfile:
        logfile.write(message)
        logfile.write("\n")

# %%
def cleanup_existing_results():
    output_to_log("[LOG] Removing pre-existing mutants from current working directory")
    os.system('rm -rf *.java/')
    output_to_log("[LOG] Cleaning up LittleDarwin results")
    os.system('rm -rf ' + littledarwin_results_path)

# %%
def back_up_original_RICK_test(target):
    output_to_log("[LOG] Backing up original RICK test as ./" + target["parent-file"] + "/original-test.java")
    backup_rick_test = "cp " + target["test-path"] + target["test-file"] + " ./" + target["parent-file"] + "/original-test.java"
    output_to_log("[LOG] Invoking " + backup_rick_test)
    os.system(backup_rick_test)

# %%
def restore_original_RICK_test(target):
    output_to_log("[LOG] Restoring original RICK test from ./" + target["parent-file"] + "/original-test.java")
    restore_rick_test = "cp" + " ./" + target["parent-file"] + "/original-test.java" + " " + target["test-path"] + target["test-file"]
    output_to_log("[LOG] Invoking " + restore_rick_test)
    os.system(restore_rick_test)

# %%
def replace_original_RICK_test_with_variant(target, variant):
    output_to_log("[LOG] Replacing original RICK test with variant " + variant)
    variant_test_file = "/test-" + variant + ".java"
    original_test_file = target["test-path"] + target["test-file"]
    replace_rick_test = "cp " + output_directory + target["mut"] + variant_test_file + " " + original_test_file
    output_to_log("[LOG] Invoking " + replace_rick_test)
    os.system(replace_rick_test)

# %%
def make_copies_of_original_RICK_test(target):
    output_to_log("[LOG] Generating variants of original RICK test")
    original_test_file = target["test-path"] + target["test-file"]
    
    test_files = [
        "/test-baseline.java",
        "/test-po.java",
        "/test-co.java",
        "/test-all.java"
    ]
    
    for i in range(len(test_files)):
        os.system("cp " + original_test_file + " " + output_directory + target["mut"] + test_files[i])
        
    if target["has-oo"]:
        os.system("cp " + original_test_file + " " + output_directory + target["mut"] + "/test-oo.java")
        create_oo_test(output_directory + target["mut"] + "/test-oo.java")
        
    create_baseline_test(output_directory + target["mut"] + test_files[0])
    create_po_test(output_directory + target["mut"] + test_files[1])
    create_co_test(output_directory + target["mut"] + test_files[2])
    create_all_oracles_test(output_directory + target["mut"] + test_files[3])

# %%
def create_baseline_test(test_file_name):
    # baseline - comment out all assertEquals and Mockito.verify statements"
    output_to_log("[LOG] Modifying " + test_file_name)
    for line in fileinput.input(test_file_name, inplace = 1): 
        if oo_string in line or po_string in line or co_string in line:
            print(re.sub(r"^(.*)", "//\\1", line), end = '')
        else:
            print(line, end = '')
    output_to_log("[LOG] Created baseline test at " + test_file_name)

# %%
def create_oo_test(test_file_name):
    # OO: comment out all Mockito.verify statements
    output_to_log("[LOG] Modifying " + test_file_name)
    for line in fileinput.input(test_file_name, inplace = 1): 
        if po_string in line or co_string in line:
            print(re.sub(r"^(.*)", "// \\1", line), end = '')
        else:
            print(line, end = '')   
    output_to_log("[LOG] Created OO test at " + test_file_name)

# %%
def create_po_test(test_file_name):
    # PO: comment out all assertEquals, Mockito.times() statements
    output_to_log("[LOG] Modifying " + test_file_name)
    for line in fileinput.input(test_file_name, inplace = 1): 
        if oo_string in line or co_string in line:
            print(re.sub(r"^(.*)", "// \\1", line), end = '')
        else:
            print(line, end = '')
    output_to_log("[LOG] Created PO test at " + test_file_name)

# %%
def create_co_test(test_file_name):
    # CO: comment out all assertEquals, Mockito.atLeastOnce() statements
    output_to_log("[LOG] Modifying " + test_file_name)
    for line in fileinput.input(test_file_name, inplace = 1): 
        if oo_string in line or po_string in line:
            print(re.sub(r"^(.*)", "// \\1", line), end = '')
        else:
            print(line, end = '')
    output_to_log("[LOG] Created CO test at " + test_file_name)

# %%
def create_all_oracles_test(test_file_name):
    # All oracles: Nothing to change, this test is equal to the original
    output_to_log("[LOG] Created test with all oracles at " + test_file_name)

# %%
def find_if_mutant_is_in_mut(target, mutant_file):
    search_string = "line number in original file: "
    found = ""
    with open(mutant_file, 'r') as fp:
        for l_no, line in enumerate(fp):
            # search string
            if search_string in line:
                found = line
                print("Processing mutant file", mutant_file)
                print("mutant found:", found)
                break
                
    result = int(re.search(r"(line number in original file:\s)(\d+)", found).group(2))
    return result >= target["mut-start-line"] and result <= target["mut-end-line"]

# %%
def get_mutant_files(parent):
    mutants = ('./' + parent + '/[0-9]*.java')
    mutant_files = sorted(glob.glob(mutants))
    return mutant_files

# %%
def copy_littledarwin_results(parent):
    output_to_log("[LOG] Copying mutants of " + parent)
    os.system('cp -r ' + littledarwin_results_path + parent + " ./")

# %%
def run_littledarwin(path):
    output_to_log("[LOG] Running littledarwin on " + path)
    process = subprocess.Popen(['python3', '-m', 'littledarwin', '-m', '-v', '-p', path, '--all'],
                               stdout=subprocess.PIPE, 
                               stderr=subprocess.PIPE)
    output_to_log("[LOG] Invoked LitteDarwin with {}".format(process.args))
    stdout, stderr = process.communicate()
    output_to_log(stdout.decode("utf-8"))
    output_to_log(stderr.decode("utf-8"))

# %%
def copy_mutant_files_to_output_directory(target):
    mutants_in_experiment_directory = experiment_directory + target["parent-file"]
    path_for_mutants = output_directory + target["mut"] + "/"
    output_to_log("[LOG] Copying littledarwin mutants to " + path_for_mutants)
    process = subprocess.Popen(['cp', '-r', mutants_in_experiment_directory, path_for_mutants],
                               stdout=subprocess.PIPE, 
                               stderr=subprocess.PIPE)
    output_to_log("[LOG] Invoked copying with {}".format(process.args))
    stdout, stderr = process.communicate()
    output_to_log(stdout.decode("utf-8"))
    output_to_log(stderr.decode("utf-8"))

# %%
def run_experiment_with_mutant_file(target, mutant_file, original_file):
    output_to_log("[LOG] Replacing original" + target["parent-file"] + " with " + mutant_file)
    replace_original_with_mutant = "cp " + mutant_file + " " + target["parent-path"] + target["parent-file"]
    output_to_log("[LOG] Invoking " + replace_original_with_mutant)
    os.system(replace_original_with_mutant)
    
    # cd into parent module, make a clean install, cd back into experiments directory
    install_parent_module(target)
        
    target_report = {
        "mut": target["mut"],
        "CUT": target["parent-fqn"],
        "mutant-file": mutant_file,
        "mutant-within-mut": True
    }
    
    # test execution
    target_report["result_baseline"] = run_baseline_tests_with_no_oracles(target)
    if target["has-oo"]:
        target_report["result-oo"] = run_oo(target)
    else:
        target_report["result-oo"] = ""
    target_report["result-po"] = run_po(target)
    target_report["result-co"] = run_co(target)
    target_report["result-all"] = run_all_oracles(target)
    
    mutation_report_file = output_directory + target["mut"] + "/mutation-report.json"
    
    with open(mutation_report_file, 'a+') as outfile:
        json.dump(target_report, outfile, indent=4)
        outfile.write(",\n")
        
    output_to_log("[LOG] Resetting " + target["parent-file"] + " to original")
    replace_mutant_with_original = "cp " + original_file + " " + target["parent-path"] + target["parent-file"]
    output_to_log("[LOG] Invoking " + replace_mutant_with_original)
    os.system(replace_mutant_with_original)

# %% [markdown]
# ## Mutation analysis

# %%
def run_mutation_analysis(target):
    global mut_mutation_log_path
    mut_mutation_log_path = output_directory + target["mut"] + "/mutation-analysis.log"
    os.makedirs(os.path.dirname(mut_mutation_log_path), exist_ok=True)
    
    output_to_log("[LOG] Initiating analysis at " + str(datetime.datetime.now()))
    output_to_log("---------------------------------------------------")
    
    # housekeeping
    cleanup_existing_results()
    output_to_log("---------------------------------------------------")

    output_to_log("[LOG] Working with " + target["mut"])
    output_to_log("[LOG] Generating mutants for its parent " + target["parent-file"])
    output_to_log("---------------------------------------------------")
    
    # run littledarwin
    run_littledarwin(target["parent-path"])    
    output_to_log("---------------------------------------------------")
    
    # copy littledarwin results to current directory
    copy_littledarwin_results(target["parent-file"])
    output_to_log("---------------------------------------------------")

    # get list of mutant files
    mutant_files = get_mutant_files(target["parent-file"])
    output_to_log("[LOG] Generated " + str(len(mutant_files)) + " mutants")
    output_to_log("---------------------------------------------------")

    # get original file
    original_file = glob.glob(r'./' + target["parent-file"] + '/original.java')[0]
    
    # back-up original RICK test
    back_up_original_RICK_test(target)
    output_to_log("---------------------------------------------------")
    
    # create variants of original RICK test
    make_copies_of_original_RICK_test(target)
    output_to_log("---------------------------------------------------")
    
    for f in range(len(mutant_files)):
        if find_if_mutant_is_in_mut(target, mutant_files[f]):
            run_experiment_with_mutant_file(target, mutant_files[f], original_file)
            output_to_log("---------------------------------------------------")
    
    # copy all mutants to output folder
    copy_mutant_files_to_output_directory(target)
    
    output_to_log("---------------------------------------------------")
    output_to_log("[LOG] Finishing analysis at " + str(datetime.datetime.now()))
    
    output_to_log("====== END OF THE LINE ======")

# %%
def main():
    global experiment_directory
    global output_directory
    global littledarwin_results_path
    global oo_string
    global po_string
    global co_string

    experiment_directory = "/home/dee/dev/rick-experiments/mutation-analysis/"
    output_directory = experiment_directory + "output/"
    littledarwin_results_path = "/home/dee/anaconda3/lib/python3.8/site-packages/littledarwin/LittleDarwinResults/"

    oo_string = "assertEquals"
    po_string = "Mockito.atLeastOnce"
    co_string = "Mockito.times"
    
    os.chdir(experiment_directory)
    targets_pdfbox = read_mut_data("/home/dee/dev/rick-experiments/mutation-analysis/pdfbox/muts-pdfbox.json")
    targets_graphhopper = read_mut_data("/home/dee/dev/rick-experiments/mutation-analysis/graphhopper/muts-graphhopper.json")
    targets_gephi = read_mut_data("/home/dee/dev/rick-experiments/mutation-analysis/gephi/muts-gephi.json")    

    print("Found", len(targets_pdfbox), "MUTs for PDFBox")
    print("Found", len(targets_graphhopper), "MUTs for GraphHopper" )
    print("Found", len(targets_gephi), "MUTs for Gephi" )
    
    
    print("Working with PDFBox MUTs")
    for target in targets_pdfbox:
        print("Currently processing", target["mut"])
        print("Details:", target)
        run_mutation_analysis(target)
    
    print("Working with GraphHopper MUTs")
    for target in targets_graphhopper:
        print(target["mut"])
        print("Details:", target)
        run_mutation_analysis(target)
    
    print("Working with Gephi MUTs")
    for target in targets_gephi:
        print(target["mut"])
        print("Details:", target)
        run_mutation_analysis(target)

# %%
main()
# Out:
# Found 33 MUTs for PDFBox
# Found 14 MUTs for GraphHopper
# Found 21 MUTs for Gephi
# Working with Gephi MUTs
# AttributeColumnsControllerImpl_addAttributeColumn_Table_String_Class
# Details: {'mut': 'AttributeColumnsControllerImpl_addAttributeColumn_Table_String_Class', 'mut-start-line': 126, 'mut-end-line': 134, 'parent-module-path': '/home/dee/dev/rick-major-review/gephi/modules/DataLaboratoryAPI/', 'parent-file': 'AttributeColumnsControllerImpl.java', 'parent-fqn': 'org.gephi.datalab.impl.AttributeColumnsControllerImpl', 'parent-path': '/home/dee/dev/rick-major-review/gephi/modules/DataLaboratoryAPI/src/main/java/org/gephi/datalab/impl/', 'has-oo': False, 'test-file': 'TestAttributeColumnsControllerImplRickGenAddAttributeValue.java', 'test-path': '/home/dee/dev/rick-major-review/rick-tests/src/test/java/org/gephi/datalab/impl/', 'test-module-path': '/home/dee/dev/rick-major-review/rick-tests/'}
# Processing mutant file ./AttributeColumnsControllerImpl.java/1.java
# mutant found: ----> line number in original file: 838
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/10.java
# mutant found: ----> line number in original file: 673
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/100.java
# mutant found: ----> line number in original file: 137
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/101.java
# mutant found: ----> line number in original file: 126
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/102.java
# mutant found: ----> line number in original file: 89
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/103.java
# mutant found: ----> line number in original file: 89
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/104.java
# mutant found: ----> line number in original file: 858
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/105.java
# mutant found: ----> line number in original file: 838
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/106.java
# mutant found: ----> line number in original file: 831
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/107.java
# mutant found: ----> line number in original file: 808
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/108.java
# mutant found: ----> line number in original file: 805
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/109.java
# mutant found: ----> line number in original file: 790
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/11.java
# mutant found: ----> line number in original file: 629
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/110.java
# mutant found: ----> line number in original file: 754
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/111.java
# mutant found: ----> line number in original file: 737
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/112.java
# mutant found: ----> line number in original file: 707
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/113.java
# mutant found: ----> line number in original file: 697
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/114.java
# mutant found: ----> line number in original file: 693
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/115.java
# mutant found: ----> line number in original file: 682
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/116.java
# mutant found: ----> line number in original file: 682
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/117.java
# mutant found: ----> line number in original file: 677
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/118.java
# mutant found: ----> line number in original file: 673
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/119.java
# mutant found: ----> line number in original file: 648
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/12.java
# mutant found: ----> line number in original file: 603
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/120.java
# mutant found: ----> line number in original file: 647
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/121.java
# mutant found: ----> line number in original file: 644
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/122.java
# mutant found: ----> line number in original file: 643
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/123.java
# mutant found: ----> line number in original file: 639
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/124.java
# mutant found: ----> line number in original file: 639
#
# Processing mutant file ./AttributeColumnsControllerImpl.java
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/56.java
# mutant found: ----> line number in original file: 547
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/57.java
# mutant found: ----> line number in original file: 542
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/58.java
# mutant found: ----> line number in original file: 520
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/59.java
# mutant found: ----> line number in original file: 520
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/6.java
# mutant found: ----> line number in original file: 707
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/60.java
# mutant found: ----> line number in original file: 511
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/61.java
# mutant found: ----> line number in original file: 511
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/62.java
# mutant found: ----> line number in original file: 506
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/63.java
# mutant found: ----> line number in original file: 506
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/64.java
# mutant found: ----> line number in original file: 501
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/65.java
# mutant found: ----> line number in original file: 501
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/66.java
# mutant found: ----> line number in original file: 496
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/67.java
# mutant found: ----> line number in original file: 496
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/68.java
# mutant found: ----> line number in original file: 491
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/69.java
# mutant found: ----> line number in original file: 491
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/7.java
# mutant found: ----> line number in original file: 697
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/70.java
# mutant found: ----> line number in original file: 486
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/71.java
# mutant found: ----> line number in original file: 486
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/72.java
# mutant found: ----> line number in original file: 481
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/73.java
# mutant found: ----> line number in original file: 481
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/74.java
# mutant found: ----> line number in original file: 476
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/75.java
# mutant found: ----> line number in original file: 476
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/76.java
# mutant found: ----> line number in original file: 467
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/77.java
# mutant found: ----> line number in original file: 467
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/78.java
# mutant found: ----> line number in original file: 458
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/79.java
# mutant found: ----> line number in original file: 428
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/8.java
# mutant found: ----> line number in original file: 682
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/80.java
# mutant found: ----> line number in original file: 423
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/81.java
# mutant found: ----> line number in original file: 418
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/82.java
# mutant found: ----> line number in original file: 393
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/83.java
# mutant found: ----> line number in original file: 386
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/84.java
# mutant found: ----> line number in original file: 381
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/85.java
# mutant found: ----> line number in original file: 374
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/86.java
# mutant found: ----> line number in original file: 369
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/87.java
# mutant found: ----> line number in original file: 332
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/88.java
# mutant found: ----> line number in original file: 321
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/89.java
# mutant found: ----> line number in original file: 294
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/9.java
# mutant found: ----> line number in original file: 677
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/90.java
# mutant found: ----> line number in original file: 278
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/91.java
# mutant found: ----> line number in original file: 269
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/92.java
# mutant found: ----> line number in original file: 260
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/93.java
# mutant found: ----> line number in original file: 251
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/94.java
# mutant found: ----> line number in original file: 242
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/95.java
# mutant found: ----> line number in original file: 217
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/96.java
# mutant found: ----> line number in original file: 207
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/97.java
# mutant found: ----> line number in original file: 154
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/98.java
# mutant found: ----> line number in original file: 150
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/99.java
# mutant found: ----> line number in original file: 144
#
# AttributeColumnsControllerImpl_canConvertColumnToDynamic_Column
# Details: {'mut': 'AttributeColumnsControllerImpl_canConvertColumnToDynamic_Column', 'mut-start-line': 520, 'mut-end-line': 539, 'parent-module-path': '/home/dee/dev/rick-major-review/gephi/modules/DataLaboratoryAPI/', 'parent-file': 'AttributeColumnsControllerImpl.java', 'parent-fqn': 'org.gephi.datalab.impl.AttributeColumnsControllerImpl', 'parent-path': '/home/dee/dev/rick-major-review/gephi/modules/DataLaboratoryAPI/src/main/java/org/gephi/datalab/impl/', 'has-oo': True, 'test-file': 'TestAttributeColumnsControllerImplRickGenCanConvertColumnToDynamic.java', 'test-path': '/home/dee/dev/rick-major-review/rick-tests/src/test/java/org/gephi/datalab/impl/', 'test-module-path': '/home/dee/dev/rick-major-review/rick-tests/'}
# Processing mutant file ./AttributeColumnsControllerImpl.java/1.java
# mutant found: ----> line number in original file: 838
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/10.java
# mutant found: ----> line number in original file: 673
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/100.java
# mutant found: ----> line number in original file: 137
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/101.java
# mutant found: ----> line number in original file: 126
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/102.java
# mutant found: ----> line number in original file: 89
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/103.java
# mutant found: ----> line number in original file: 89
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/104.java
# mutant found: ----> line number in original file: 858
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/105.java
# mutant found: ----> line number in original file: 838
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/106.java
# mutant found: ----> line number in original file: 831
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/107.java
# mutant found: ----> line number in original file: 808
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/108.java
# mutant found: ----> line number in original file: 805
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/109.java
# mutant found: ----> line number in original file: 790
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/11.java
# mutant found: ----> line number in original file: 629
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/110.java
# mutant found: ----> line number in original file: 754
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/111.java
# mutant found: ----> line number in original file: 737
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/112.java
# mutant found: ----> line number in original file: 707
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/113.java
# mutant found: ----> line number in original file: 697
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/114.java
# mutant found: ----> line number in original file: 693
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/115.java
# mutant found: ----> line number in original file: 682
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/116.java
# mutant found: ----> line number in original file: 682
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/117.java
# mutant found: ----> line number in original file: 677
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/118.java
# mutant found: ----> line number in original file: 673
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/119.java
# mutant found: ----> line number in original file: 648
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/12.java
# mutant found: ----> line number in original file: 603
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/120.java
# mutant found: ----> line number in original file: 647
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/121.java
# mutant found: ----> line number in original file: 644
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/122.java
# mutant found: ----> line number in original file: 643
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/123.java
# mutant found: ----> line number in original file: 639
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/124.java
# mutant found: ----> line number in original file: 639
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/125.java
# mutant found: ----> line number in original file: 635
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/126.java
# mutant found: ----> line number in original file: 629
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/127.java
# mutant found: ----> line number in original file: 603
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/128.java
# mutant found: ----> line number in original file: 596
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/129.java
# mutant found: ----> line number in original file: 572
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/13.java
# mutant found: ----> line number in original file: 596
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/130.java
# mutant found: ----> line number in original file: 565
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/131.java
# mutant found: ----> line number in original file: 492
#
# Processing mutant file ./AttributeColumnsControllerImpl.java/132.java
# mutant found: ----> line number in original file: 487
#
# ...
# mutant found: ----> line number in original file: 488
#
# Processing mutant file ./YifanHuLayout.java/70.java
# mutant found: ----> line number in original file: 485
#
# Processing mutant file ./YifanHuLayout.java/71.java
# mutant found: ----> line number in original file: 463
#
# Processing mutant file ./YifanHuLayout.java/72.java
# mutant found: ----> line number in original file: 459
#
# Processing mutant file ./YifanHuLayout.java/73.java
# mutant found: ----> line number in original file: 452
#
# Processing mutant file ./YifanHuLayout.java/74.java
# mutant found: ----> line number in original file: 433
#
# Processing mutant file ./YifanHuLayout.java/75.java
# mutant found: ----> line number in original file: 426
#
# Processing mutant file ./YifanHuLayout.java/76.java
# mutant found: ----> line number in original file: 419
#
# Processing mutant file ./YifanHuLayout.java/77.java
# mutant found: ----> line number in original file: 412
#
# Processing mutant file ./YifanHuLayout.java/78.java
# mutant found: ----> line number in original file: 405
#
# Processing mutant file ./YifanHuLayout.java/79.java
# mutant found: ----> line number in original file: 398
#
# Processing mutant file ./YifanHuLayout.java/8.java
# mutant found: ----> line number in original file: 487
#
# Processing mutant file ./YifanHuLayout.java/80.java
# mutant found: ----> line number in original file: 391
#
# Processing mutant file ./YifanHuLayout.java/81.java
# mutant found: ----> line number in original file: 384
#
# Processing mutant file ./YifanHuLayout.java/82.java
# mutant found: ----> line number in original file: 377
#
# Processing mutant file ./YifanHuLayout.java/83.java
# mutant found: ----> line number in original file: 370
#
# Processing mutant file ./YifanHuLayout.java/84.java
# mutant found: ----> line number in original file: 363
#
# Processing mutant file ./YifanHuLayout.java/85.java
# mutant found: ----> line number in original file: 356
#
# Processing mutant file ./YifanHuLayout.java/86.java
# mutant found: ----> line number in original file: 349
#
# Processing mutant file ./YifanHuLayout.java/87.java
# mutant found: ----> line number in original file: 342
#
# Processing mutant file ./YifanHuLayout.java/88.java
# mutant found: ----> line number in original file: 338
#
# Processing mutant file ./YifanHuLayout.java/89.java
# mutant found: ----> line number in original file: 333
#
# Processing mutant file ./YifanHuLayout.java/9.java
# mutant found: ----> line number in original file: 486
#
# Processing mutant file ./YifanHuLayout.java/90.java
# mutant found: ----> line number in original file: 329
#
# Processing mutant file ./YifanHuLayout.java/91.java
# mutant found: ----> line number in original file: 261
#
# Processing mutant file ./YifanHuLayout.java/92.java
# mutant found: ----> line number in original file: 249
#
# Processing mutant file ./YifanHuLayout.java/93.java
# mutant found: ----> line number in original file: 229
#
# Processing mutant file ./YifanHuLayout.java/94.java
# mutant found: ----> line number in original file: 158
#
# Processing mutant file ./YifanHuLayout.java/95.java
# mutant found: ----> line number in original file: 145
#
# Processing mutant file ./YifanHuLayout.java/96.java
# mutant found: ----> line number in original file: 145
#
# Processing mutant file ./YifanHuLayout.java/97.java
# mutant found: ----> line number in original file: 128
#
# Processing mutant file ./YifanHuLayout.java/98.java
# mutant found: ----> line number in original file: 110
#
# Processing mutant file ./YifanHuLayout.java/99.java
# mutant found: ----> line number in original file: 106
#
# YifanHuLayout_SpringForce_calculateForce_Node_Node_float
# Details: {'mut': 'YifanHuLayout_SpringForce_calculateForce_Node_Node_float', 'mut-start-line': 451, 'mut-end-line': 457, 'parent-module-path': '/home/dee/dev/rick-major-review/gephi/modules/LayoutPlugin/', 'parent-file': 'YifanHuLayout.java', 'parent-fqn': 'org.gephi.layout.plugin.force.yifanHu.YifanHuLayout', 'parent-path': '/home/dee/dev/rick-major-review/gephi/modules/LayoutPlugin/src/main/java/org/gephi/layout/plugin/force/yifanHu/', 'has-oo': False, 'test-file': 'TestSpringForceRickGen.java', 'test-path': '/home/dee/dev/rick-major-review/rick-tests/src/test/java/org/gephi/layout/plugin/force/yifanHu/', 'test-module-path': '/home/dee/dev/rick-major-review/rick-tests/'}
# Processing mutant file ./YifanHuLayout.java/1.java
# mutant found: ----> line number in original file: 314
#
# Processing mutant file ./YifanHuLayout.java/10.java
# mutant found: ----> line number in original file: 419
#
# Processing mutant file ./YifanHuLayout.java/100.java
# mutant found: ----> line number in original file: 102
#
# Processing mutant file ./YifanHuLayout.java/101.java
# mutant found: ----> line number in original file: 97
#
# Processing mutant file ./YifanHuLayout.java/102.java
# mutant found: ----> line number in original file: 90
#
# Processing mutant file ./YifanHuLayout.java/103.java
# mutant found: ----> line number in original file: 267
#
# Processing mutant file ./YifanHuLayout.java/104.java
# mutant found: ----> line number in original file: 230
#
# Processing mutant file ./YifanHuLayout.java/105.java
# mutant found: ----> line number in original file: 131
#
# Processing mutant file ./YifanHuLayout.java/106.java
# mutant found: ----> line number in original file: 114
#
# Processing mutant file ./YifanHuLayout.java/107.java
# mutant found: ----> line number in original file: 112
#
# Processing mutant file ./YifanHuLayout.java/108.java
# mutant found: ----> line number in original file: 92
#
# Processing mutant file ./YifanHuLayout.java/109.java
# mutant found: ----> line number in original file: 151
#
# Processing mutant file ./YifanHuLayout.java/11.java
# mutant found: ----> line number in original file: 405
#
# Processing mutant file ./YifanHuLayout.java/110.java
# mutant found: ----> line number in original file: 113
#
# Processing mutant file ./YifanHuLayout.java/12.java
# mutant found: ----> line number in original file: 391
#
# Processing mutant file ./YifanHuLayout.java/13.java
# mutant found: ----> line number in original file: 377
#
# Processing mutant file ./YifanHuLayout.java/14.java
# mutant found: ----> line number in original file: 370
#
# Processing mutant file ./YifanHuLayout.java/15.java
# mutant found: ----> line number in original file: 356
#
# Processing mutant file ./YifanHuLayout.java/16.java
# mutant found: ----> line number in original file: 342
#
# Processing mutant file ./YifanHuLayout.java/17.java
# mutant found: ----> line number in original file: 333
#
# Processing mutant file ./YifanHuLayout.java/18.java
# mutant found: ----> line number in original file: 145
#
# Processing mutant file ./YifanHuLayout.java/19.java
# mutant found: ----> line number in original file: 490
#
# Processing mutant file ./YifanHuLayout.java/2.java
# mutant found: ----> line number in original file: 289
#
# Processing mutant file ./YifanHuLayout.java/20.java
# mutant found: ----> line number in original file: 488
#
# Processing mutant file ./YifanHuLayout.java/21.java
# mutant found: ----> line number in original file: 494
#
# Processing mutant file ./YifanHuLayout.java/22.java
# mutant found: ----> line number in original file: 460
#
# Processing mutant file ./YifanHuLayout.java/23.java
# mutant found: ----> line number in original file: 456
# Processing mutant file ./YifanHuLayout.java/24.java
# mutant found: ----> line number in original file: 427
#
# Processing mutant file ./YifanHuLayout.java/25.java
# mutant found: ----> line number in original file: 413
#
# Processing mutant file ./YifanHuLayout.java/26.java
# mutant found: ----> line number in original file: 399
#
# Processing mutant file ./YifanHuLayout.java/27.java
# mutant found: ----> line number in original file: 385
#
# Processing mutant file ./YifanHuLayout.java/28.java
# mutant found: ----> line number in original file: 364
#
# Processing mutant file ./YifanHuLayout.java/29.java
# mutant found: ----> line number in original file: 350
#
# Processing mutant file ./YifanHuLayout.java/3.java
# mutant found: ----> line number in original file: 267
#
# Processing mutant file ./YifanHuLayout.java/30.java
# mutant found: ----> line number in original file: 339
#
# Processing mutant file ./YifanHuLayout.java/31.java
# mutant found: ----> line number in original file: 330
#
# Processing mutant file ./YifanHuLayout.java/32.java
# mutant found: ----> line number in original file: 225
#
# Processing mutant file ./YifanHuLayout.java/33.java
# mutant found: ----> line number in original file: 107
#
# Processing mutant file ./YifanHuLayout.java/34.java
# mutant found: ----> line number in original file: 103
#
# Processing mutant file ./YifanHuLayout.java/35.java
# mutant found: ----> line number in original file: 99
#
# Processing mutant file ./YifanHuLayout.java/36.java
# mutant found: ----> line number in original file: 308
#
# Processing mutant file ./YifanHuLayout.java/37.java
# mutant found: ----> line number in original file: 149
#
# Processing mutant file ./YifanHuLayout.java/38.java
# mutant found: ----> line number in original file: 486
#
# Processing mutant file ./YifanHuLayout.java/39.java
# mutant found: ----> line number in original file: 453
#
# Processing mutant file ./YifanHuLayout.java/4.java
# mutant found: ----> line number in original file: 485
#
# Processing mutant file ./YifanHuLayout.java/40.java
# mutant found: ----> line number in original file: 277
#
# Processing mutant file ./YifanHuLayout.java/41.java
# mutant found: ----> line number in original file: 268
#
# Processing mutant file ./YifanHuLayout.java/42.java
# mutant found: ----> line number in original file: 238
#
# Processing mutant file ./YifanHuLayout.java/43.java
# mutant found: ----> line number in original file: 159
#
# Processing mutant file ./YifanHuLayout.java/44.java
# mutant found: ----> line number in original file: 107
#
# Processing mutant file ./YifanHuLayout.java/45.java
# mutant found: ----> line number in original file: 103
#
# Processing mutant file ./YifanHuLayout.java/46.java
# mutant found: ----> line number in original file: 488
#
# Processing mutant file ./YifanHuLayout.java/47.java
# mutant found: ----> line number in original file: 488
#
# Processing mutant file ./YifanHuLayout.java/48.java
# mutant found: ----> line number in original file: 488
#
# Processing mutant file ./YifanHuLayout.java/49.java
# mutant found: ----> line number in original file: 488
#
# Processing mutant file ./YifanHuLayout.java/5.java
# mutant found: ----> line number in original file: 485
#
# Processing mutant file ./YifanHuLayout.java/50.java
# mutant found: ----> line number in original file: 487
#
# Processing mutant file ./YifanHuLayout.java/51.java
# mutant found: ----> line number in original file: 486
#
# Processing mutant file ./YifanHuLayout.java/52.java
# mutant found: ----> line number in original file: 455
#
# Processing mutant file ./YifanHuLayout.java/53.java
# mutant found: ----> line number in original file: 454
#
# Processing mutant file ./YifanHuLayout.java/54.java
# mutant found: ----> line number in original file: 453
#
# Processing mutant file ./YifanHuLayout.java/55.java
# mutant found: ----> line number in original file: 317
#
# Processing mutant file ./YifanHuLayout.java/56.java
# mutant found: ----> line number in original file: 154
#
# Processing mutant file ./YifanHuLayout.java/57.java
# mutant found: ----> line number in original file: 137
#
# Processing mutant file ./YifanHuLayout.java/58.java
# mutant found: ----> line number in original file: 132
#
# Processing mutant file ./YifanHuLayout.java/59.java
# mutant found: ----> line number in original file: 132
#
# Processing mutant file ./YifanHuLayout.java/6.java
# mutant found: ----> line number in original file: 463
#
# Processing mutant file ./YifanHuLayout.java/60.java
# mutant found: ----> line number in original file: 123
#
# Processing mutant file ./YifanHuLayout.java/61.java
# mutant found: ----> line number in original file: 120
#
# Processing mutant file ./YifanHuLayout.java/62.java
# mutant found: ----> line number in original file: 116
#
# Processing mutant file ./YifanHuLayout.java/63.java
# mutant found: ----> line number in original file: 92
#
# Processing mutant file ./YifanHuLayout.java/64.java
# mutant found: ----> line number in original file: 92
#
# Processing mutant file ./YifanHuLayout.java/65.java
# mutant found: ----> line number in original file: 267
#
# Processing mutant file ./YifanHuLayout.java/66.java
# mutant found: ----> line number in original file: 230
#
# Processing mutant file ./YifanHuLayout.java/67.java
# mutant found: ----> line number in original file: 131
#
# Processing mutant file ./YifanHuLayout.java/68.java
# mutant found: ----> line number in original file: 489
#
# Processing mutant file ./YifanHuLayout.java/69.java
# mutant found: ----> line number in original file: 267
#
# Processing mutant file ./YifanHuLayout.java/7.java
# mutant found: ----> line number in original file: 452
#
# Processing mutant file ./YifanHuLayout.java/70.java
# mutant found: ----> line number in original file: 485
#
# Processing mutant file ./YifanHuLayout.java/71.java
# mutant found: ----> line number in original file: 463
#
# Processing mutant file ./YifanHuLayout.java/72.java
# mutant found: ----> line number in original file: 459
#
# Processing mutant file ./YifanHuLayout.java/73.java
# mutant found: ----> line number in original file: 452
#
# Processing mutant file ./YifanHuLayout.java/74.java
# mutant found: ----> line number in original file: 433
#
# Processing mutant file ./YifanHuLayout.java/75.java
# mutant found: ----> line number in original file: 426
#
# Processing mutant file ./YifanHuLayout.java/76.java
# mutant found: ----> line number in original file: 419
#
# Processing mutant file ./YifanHuLayout.java/77.java
# mutant found: ----> line number in original file: 412
#
# Processing mutant file ./YifanHuLayout.java/78.java
# mutant found: ----> line number in original file: 405
#
# Processing mutant file ./YifanHuLayout.java/79.java
# mutant found: ----> line number in original file: 398
#
# Processing mutant file ./YifanHuLayout.java/8.java
# mutant found: ----> line number in original file: 452
#
# Processing mutant file ./YifanHuLayout.java/80.java
# mutant found: ----> line number in original file: 391
#
# Processing mutant file ./YifanHuLayout.java/81.java
# mutant found: ----> line number in original file: 384
#
# Processing mutant file ./YifanHuLayout.java/82.java
# mutant found: ----> line number in original file: 377
#
# Processing mutant file ./YifanHuLayout.java/83.java
# mutant found: ----> line number in original file: 370
#
# Processing mutant file ./YifanHuLayout.java/84.java
# mutant found: ----> line number in original file: 363
#
# Processing mutant file ./YifanHuLayout.java/85.java
# mutant found: ----> line number in original file: 356
#
# Processing mutant file ./YifanHuLayout.java/86.java
# mutant found: ----> line number in original file: 349
#
# Processing mutant file ./YifanHuLayout.java/87.java
# mutant found: ----> line number in original file: 342
#
# Processing mutant file ./YifanHuLayout.java/88.java
# mutant found: ----> line number in original file: 338
#
# Processing mutant file ./YifanHuLayout.java/89.java
# mutant found: ----> line number in original file: 333
#
# Processing mutant file ./YifanHuLayout.java/9.java
# mutant found: ----> line number in original file: 433
#
# Processing mutant file ./YifanHuLayout.java/90.java
# mutant found: ----> line number in original file: 329
#
# Processing mutant file ./YifanHuLayout.java/91.java
# mutant found: ----> line number in original file: 261
#
# Processing mutant file ./YifanHuLayout.java/92.java
# mutant found: ----> line number in original file: 249
#
# Processing mutant file ./YifanHuLayout.java/93.java
# mutant found: ----> line number in original file: 229
#
# Processing mutant file ./YifanHuLayout.java/94.java
# mutant found: ----> line number in original file: 158
#
# Processing mutant file ./YifanHuLayout.java/95.java
# mutant found: ----> line number in original file: 145
#
# Processing mutant file ./YifanHuLayout.java/96.java
# mutant found: ----> line number in original file: 145
#
# Processing mutant file ./YifanHuLayout.java/97.java
# mutant found: ----> line number in original file: 128
#
# Processing mutant file ./YifanHuLayout.java/98.java
# mutant found: ----> line number in original file: 110
#
# Processing mutant file ./YifanHuLayout.java/99.java
# mutant found: ----> line number in original file: 106
